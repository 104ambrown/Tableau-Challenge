# %%
#importing dependencies
import glob
import pandas as pd

# %%
#establishing a base path to read in all csvs
files = glob.glob('C:/Users/abrow/Desktop/EMERSON_BOOTCAMP/BOOTCAMP_AMB/Homeworks/HW13_01-29-22_Tableau_Homework/Tableau-challenge/CitiBike_Data/2015*.csv')

#creating an empty list to store the dataframes
frame = []

#writing a simple loops of what to do with the csvs
for file in files:
    frame.append(pd.read_csv(file))

#Concatenate dataframes into 1
citibike2015_df = pd.concat(frame)

# %%
citibike2015_df.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           241  4/1/2015 00:00:23  4/1/2015 00:04:25               494
# 1           578  4/1/2015 00:00:52  4/1/2015 00:10:31                82
# 2           484  4/1/2015 00:01:28  4/1/2015 00:09:33               223
# 3          1144  4/1/2015 00:01:31  4/1/2015 00:20:36               393
# 4          1023  4/1/2015 00:01:36  4/1/2015 00:18:40               212
#
#         start station name  start station latitude  start station longitude  \
# 0          W 26 St & 8 Ave               40.747348               -73.997236
# 1   St James Pl & Pearl St               40.711174               -74.000165
# 2          W 13 St & 7 Ave               40.737815               -73.999947
# 3        E 5 St & Avenue C               40.722992               -73.979955
# 4  W 16 St & The High Line               40.743349               -74.006818
#
#    end station id       end station name  end station latitude  \
# ...

# %%
#Converting starttime and endtime to datetime to prepare for splitting and inserting into new columns
citibike2015_df['Start Date'] = pd.to_datetime(citibike2015_df['starttime']).dt.date
citibike2015_df['Start Time'] = pd.to_datetime(citibike2015_df['starttime']).dt.time
citibike2015_df['Stop Date'] = pd.to_datetime(citibike2015_df['stoptime']).dt.date
citibike2015_df['Stop Time'] = pd.to_datetime(citibike2015_df['stoptime']).dt.timecitibike2015_df

# %%
# Writing a function to convert tripduration from seconds to hours, minutes, seconds in a new column
def format_duration(row):
    seconds = row.tripduration
    minutes, seconds = divmod(seconds, 60)
    hours, minutes = divmod(minutes, 60)
    return '{:02d} : {:02d} : {:02d}'.format(hours, minutes, seconds)

# applying the function to the dataframe
citibike2015_df['Trip Duration'] = citibike2015_df.apply(format_duration, axis=1)
citibike2015_df.head()

# %%
# Getting length of dataframe
total_rows = citibike2014_df.count()
print(total_rows +1)

# %%
citibike2015_df.to_csv_folder(path_or_buf="C:/Users/abrow/Desktop/EMERSON_BOOTCAMP/BOOTCAMP_AMB/Homeworks/HW13_01-29-22_Tableau_Homework/Tableau-challenge/Clean_data_*.csv",  num_files=3, index=False, header=True, encoding="utf-8")
